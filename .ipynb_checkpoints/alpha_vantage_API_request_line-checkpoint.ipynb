# %%
import numpy as np

import datetime
from influxdb_client import InfluxDBClient, WritePrecision, WriteOptions
from influxdb_client.client.write_api import ASYNCHRONOUS, SYNCHRONOUS, PointSettings
from pytz import UTC
from influxdb_client.client.write.point import EPOCH
import ciso8601

from alpha_vantage.cryptocurrencies import CryptoCurrencies

# %%
apikeys = {"alejo": "QQWAHPE5V4QGJ5V7"}

parameters = {
    "alpha_vantage": {
        "key": apikeys["alejo"], # Claim your free API key here: https://www.alphavantage.co/support/#api-key
        "symbol": "ETH",
        "market": "USD",
        "key_adjusted_close": "5. adjusted close",
    },
    "influx_client":{
        "url": "http://localhost:8086",
        "token": "lfxC2lYwGfnLPGt7viM80qZASpVFwu7z0ELorZEdAqyw5AH94V7TfgrpM8ga-vhtLd0LkxN2i5uKQ82_p2V7lg==",
        "org": "influxProject",
        "timeout" : 300000
    },
    "influx_write_api":{
        "bucket": "dailyMetricsETH",
        "batch_size": 800,
        "flush_interval": 10000
    }
}

# %%
def retrieve_digital_currency_daily(parameters):
    
    '''
    parameters: dictionary containing the parameters to connect and retrieve information from Alpha Vantage API
    
    returns: data and meta_data dictionaries
    '''
    
    cc = CryptoCurrencies(key=parameters["alpha_vantage"]["key"])
    data, meta_data = cc.get_digital_currency_daily(symbol=parameters["alpha_vantage"]["symbol"], market=parameters["alpha_vantage"]["market"])
    
    return data, meta_data

# %%
data, meta_data = retrieve_digital_currency_daily(parameters)

# %%
print(meta_data)
# Out:
# {'1. Information': 'Daily Prices and Volumes for Digital Currency', '2. Digital Currency Code': 'ETH', '3. Digital Currency Name': 'Ethereum', '4. Market Code': 'USD', '5. Market Name': 'United States Dollar', '6. Last Refreshed': '2021-09-19 00:00:00', '7. Time Zone': 'UTC'}

# %%
#print(data)

# %% [markdown]
# '2018-12-25': {'1a. open (USD)': '138.01000000', '1b. open (USD)': '138.01000000', '2a. high (USD)': '139.26000000', '2b. high (USD)': '139.26000000', '3a. low (USD)': '119.68000000', '3b. low (USD)': '119.68000000', '4a. close (USD)': '127.60000000', '4b. close (USD)': '127.60000000', '5. volume': '1076164.12809000', '6. market cap (USD)': '1076164.12809000'}

# %%
observation = [value for key, value in data.items()]
observation.reverse()
observation_number = len(observation)

# %%
 observation[0]
# Out:
# {'1a. open (USD)': '138.01000000',
#  '1b. open (USD)': '138.01000000',
#  '2a. high (USD)': '139.26000000',
#  '2b. high (USD)': '139.26000000',
#  '3a. low (USD)': '119.68000000',
#  '3b. low (USD)': '119.68000000',
#  '4a. close (USD)': '127.60000000',
#  '4b. close (USD)': '127.60000000',
#  '5. volume': '1076164.12809000',
#  '6. market cap (USD)': '1076164.12809000'}

# %%
tag_key = [key[3:] for key, value in meta_data.items()]
tag_value = [value for key, value in meta_data.items()]

# %%
tag_key
# Out:
# ['Information',
#  'Digital Currency Code',
#  'Digital Currency Name',
#  'Market Code',
#  'Market Name',
#  'Last Refreshed',
#  'Time Zone']

# %%
tag_value
# Out:
# ['Daily Prices and Volumes for Digital Currency',
#  'ETH',
#  'Ethereum',
#  'USD',
#  'United States Dollar',
#  '2021-09-19 00:00:00',
#  'UTC']

# %%
field_name = [key for key, value in observation[0].items()]
field_number = len(field_name)
field_name
# Out:
# ['1a. open (USD)',
#  '1b. open (USD)',
#  '2a. high (USD)',
#  '2b. high (USD)',
#  '3a. low (USD)',
#  '3b. low (USD)',
#  '4a. close (USD)',
#  '4b. close (USD)',
#  '5. volume',
#  '6. market cap (USD)']

# %%
fields = ''
for l in range(0, field_number):
    fields += f'{field_name[l][:]}='.replace(" (USD)", "").replace(".", "").replace(" ", "_") + observation[0][f'{field_name[l]}']+ ","

fields = fields[:-1]
print(fields)
# Out:
# 1a_open=138.01000000,1b_open=138.01000000,2a_high=139.26000000,2b_high=139.26000000,3a_low=119.68000000,3b_low=119.68000000,4a_close=127.60000000,4b_close=127.60000000,5_volume=1076164.12809000,6_market_cap=1076164.12809000

# %%
measurement_name = str(f"{tag_value[0]},".replace(" ", "_"))
measurement_name
# Out:
# 'Daily_Prices_and_Volumes_for_Digital_Currency,'

# %%
def digital_currency_daily_to_line(data, meta_data):

    '''

    data: dictionary containing the Alpha Vantage API request's response

    meta_data: dictionary containing the Alpha Vantage API request's metadata

    returns: list with measurements in line protocol 

    '''

    observation = [value for key, value in data.items()]
    observation.reverse()
    observation_number = len(observation)

    tag_key = [key[3:] for key, value in meta_data.items()]
    tag_value = [value for key, value in meta_data.items()]

    field_name = [key for key, value in observation[0].items()]
    field_number = len(field_name)

    unix_ns_timestamp = [str(int((UTC.localize(ciso8601.parse_datetime(date)) - EPOCH).total_seconds() * 1e9)) for date in data.keys()]
    unix_ns_timestamp.reverse()

    measurement_name = str(f"{tag_value[0]},".replace(" ", "_"))

    tags = ''

    lines = []

    for m in [1, 2, 3, 4]:                                # THIS INDEXES HAVE TO BE ADAPTED BY HAND HAND FOR EACH METRIC OF INTEREST
        tags += f"{tag_key[m]}={tag_value[m]}," 

    tags = tags[:-1].replace(" ", "_")

    for k in range(0, observation_number):
        fields = ''
        
        for l in range(0, field_number):
            fields += f'{field_name[l][:]}='.replace(" (USD)", "").replace(".", "").replace(" ", "_") + observation[k][f'{field_name[l]}']+ ","

        fields = fields[:-1]

        line = str(measurement_name
             + tags
             + " "
             + fields
             + " "
             + unix_ns_timestamp[k])

        lines.append(line)
    return lines

# %%
data, meta_data = retrieve_daily_adjusted_data(parameters)

# %%
lines = digital_currency_daily_to_line(data, meta_data)

# %%
lines

# %%
with InfluxDBClient(url=parameters["influx_client"]["url"], token=parameters["influx_client"]["token"], org=parameters["influx_client"]["org"], timeout=parameters["influx_client"]["timeout"], enable_gzip=False, debug=True) as client:
    
    with client.write_api(write_options=WriteOptions(batch_size=parameters["influx_write_api"]["batch_size"])) as write_api:
        
        write_api.write(bucket=parameters["influx_write_api"]["bucket"], record=lines)
# Out:
# send: b'POST /api/v2/write?org=influxProject&bucket=alphaVantageTest&precision=ns HTTP/1.1\r\nHost: localhost:8086\r\nAccept-Encoding: identity\r\nContent-Length: 1304115\r\nContent-Encoding: identity\r\nContent-Type: text/plain\r\nAccept: application/json\r\nAuthorization: Token lfxC2lYwGfnLPGt7viM80qZASpVFwu7z0ELorZEdAqyw5AH94V7TfgrpM8ga-vhtLd0LkxN2i5uKQ82_p2V7lg==\r\nUser-Agent: influxdb-client-python/1.20.0\r\n\r\n'
# send: b'Daily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=98.5,high=98.81,low=96.37,close=96.75,adjusted_close=59.358271344,volume=9551800,dividend_amount=0.0000,split_coefficient=1.0 941414400000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=96.75,high=96.81,low=93.69,close=94.81,adjusted_close=58.1680383062,volume=11105400,dividend_amount=0.0000,split_coefficient=1.0 941500800000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=95.87,high=95.94,low=93.5,close=94.37,adjusted_close=57.8980885451,volume=10369100,dividend_amount=0.0000,split_coefficient=1.0 941587200000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=94.44,high=94.44,low=90.0,close=91.56,adjusted_close=56.1740912068,volume=16697600,dividend_amount=0.0000,split_coefficient=1.0 941673600000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=92.75,high=92.94,low=90.19,close=90.25,adjusted_close=55.3703771452,volume=13737600,dividend_amount=0.0000,split_coefficient=1.0 941760000000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=90.5,high=93.94,low=90.5,close=93.94,adjusted_close=57.7078966679,volume=8522300,dividend_amount=0.1200,split_coefficient=1.0 942019200000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=95.06,high=95.5,low=92.12,close=93.62,adjusted_close=57.5113187785,volume=9551200,dividend_amount=0.0000,split_coefficient=1.0 942105600000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=94.62,high=97.06,low=94.12,close=97.0,adjusted_close=59.5876727357,volume=8680300,dividend_amount=0.0000,split_coefficient=1.0 942192000000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=97.5,high=97.5,low=94.87,close=95.0,adjusted_close=58.3590609267,volume=7147500,dividend_amount=0.0000,split_coefficient=1.0 942278400000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=96.0,high=96.25,low=93.0,close=95.87,adjusted_close=58.8935070636,volume=9668400,dividend_amount=0.0000,split_coefficient=1.0 942364800000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=96.0,high=96.37,low=93.87,close=94.06,adjusted_close=57.7816133764,volume=6259400,dividend_amount=0.0000,split_coefficient=1.0 942624000000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=94.62,high=95.0,low=93.0,close=94.62,adjusted_close=58.125624683,volume=8537400,dividend_amount=0.0000,split_coefficient=1.0 942710400000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=94.87,high=94.87,low=92.62,close=93.75,adjusted_close=57.5911785461,volume=8355100,dividend_amount=0.0000,split_coefficient=1.0 942796800000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=94.0,high=98.25,low=93.56,close=98.0,adjusted_close=60.2019786401,volume=18720500,dividend_amount=0.0000,split_coefficient=1.0 942883200000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=99.0,high=105.12,low=98.37,close=103.94,adjusted_close=63.8509557128,volume=19678400,dividend_amount=0.0000,split_coefficient=1.0 942969600000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=105.5,high=108.44,low=104.44,close=107.87,adjusted_close=66.2651779175,volume=13681600,dividend_amount=0.0000,split_coefficient=1.0 943228800000000000\nDaily_Time_Series_with_Splits_and_Dividend_Events,Symbol=IBM,Time_Zone=US/Eastern open=108.81,high=109.87,low=106.0,close=106.06,adjusted_close=65.1532842303,volume=10665200,dividend_amount=0.0000,split_coefficient=1.0 943315200000000000\nD ...
# reply: 'HTTP/1.1 500 Internal Server Error\r\n'
# header: Content-Type: application/json; charset=utf-8
# header: X-Platform-Error-Code: internal error
# header: Date: Sat, 11 Sep 2021 22:19:32 GMT
# header: Content-Length: 90
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# /var/folders/2r/tslsrd0559z8j7x6341kbsbw0000gn/T/ipykernel_42639/3314888289.py in <module>
#       3     with client.write_api(write_options=SYNCHRONOUS) as write_api:
#       4
# ----> 5         write_api.write(bucket=parameters["influx_write_api"]["bucket"], record=lines)
#
# ~/Projects/ml-for-finance/ml-for-finance-env/lib/python3.9/site-packages/influxdb_client/client/write_api.py in write(self, bucket, org, record, write_precision, **kwargs)
#     253             return self._post_write(_async_req, bucket, org, final_string, payload[0])
#     254
# --> 255         results = list(map(write_payload, payloads.items()))
#     256         if not _async_req:
#     257             return None
#
# ~/Projects/ml-for-finance/ml-for-finance-env/lib/python3.9/site-packages/influxdb_client/client/write_api.py in write_payload(payload)
#     251         def write_payload(payload):
#     252             final_string = b'\n'.join(payload[1])
# --> 253             return self._post_write(_async_req, bucket, org, final_string, payload[0])
#     254
#     255         results = list(map(write_payload, payloads.items()))
#
# ~/Projects/ml-for-finance/ml-for-finance-env/lib/python3.9/site-packages/influxdb_client/client/write_api.py in _post_write(self, _async_req, bucket, org, body, precision, **kwargs)
#     383     def _post_write(self, _async_req, bucket, org, body, precision, **kwargs):
#     384
# --> 385         return self._write_service.post_write(org=org, bucket=bucket, body=body, precision=precision,
#     386                                               async_req=_async_req, content_encoding="identity",
#     387                                               content_type="text/plain; charset=utf-8",
#
# ~/Projects/ml-for-finance/ml-for-finance-env/lib/python3.9/site-packages/influxdb_client/service/write_service.py in post_write(self, org, bucket, body, **kwargs)
#      62             return self.post_write_with_http_info(org, bucket, body, **kwargs)  # noqa: E501
#      63         else:
# ---> 64             (data) = self.post_write_with_http_info(org, bucket, body, **kwargs)  # noqa: E501
#      65             return data
#      66
#
# ~/Projects/ml-for-finance/ml-for-finance-env/lib/python3.9/site-packages/influxdb_client/service/write_service.py in post_write_with_http_info(self, org, bucket, body, **kwargs)
#     166             urlopen_kw = kwargs['urlopen_kw']
#     167
# --> 168         return self.api_client.call_api(
#     169             '/api/v2/write', 'POST',
#     170             path_params,
#
# ~/Projects/ml-for-finance/ml-for-finance-env/lib/python3.9/site-packages/influxdb_client/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, urlopen_kw)
#     339         """
#     340         if not async_req:
# --> 341             return self.__call_api(resource_path, method,
#     342                                    path_params, query_params, header_params,
#     343                                    body, post_params, files,
#
# ~/Projects/ml-for-finance/ml-for-finance-env/lib/python3.9/site-packages/influxdb_client/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, urlopen_kw)
#     169
#     170         # perform request and return response
# --> 171         response_data = self.request(
#     172             method, url, query_params=query_params, headers=header_params,
#     173             post_params=post_params, body=body,
#
# ~/Projects/ml-for-finance/ml-for-finance-env/lib/python3.9/site-packages/influxdb_client/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout, **urlopen_kw)
#     384                                             **urlopen_kw)
#     385         elif method == "POST":
# --> 386             return self.rest_client.POST(url,
#     387                                          query_params=query_params,
#     388                                          headers=headers,
#
# ~/Projects/ml-for-finance/ml-for-finance-env/lib/python3.9/site-packages/influxdb_client/rest.py in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout, **urlopen_kw)
#     300              body=None, _preload_content=True, _request_timeout=None, **urlopen_kw):
#     301         """Perform POST HTTP request."""
# --> 302         return self.request("POST", url,
#     303                             headers=headers,
#     304                             query_params=query_params,
#
# ~/Projects/ml-for-finance/ml-for-finance-env/lib/python3.9/site-packages/influxdb_client/rest.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout, **urlopen_kw)
#     250
#     251         if not 200 <= r.status <= 299:
# --> 252             raise ApiException(http_resp=r)
#     253
#     254         return r
#
# ApiException: (500)
# Reason: Internal Server Error
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'X-Platform-Error-Code': 'internal error', 'Date': 'Sat, 11 Sep 2021 22:19:32 GMT', 'Content-Length': '90'})
# HTTP response body: {"code":"internal error","message":"unexpected error writing points to database: timeout"}

# %%
WriteOptions(batch_size=parameters["influx_write_api"]["batch_size"], flush_interval=parameters["influx_write_api"]["flush_interval"])
