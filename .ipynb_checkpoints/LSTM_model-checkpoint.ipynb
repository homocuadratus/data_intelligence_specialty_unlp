# %% [markdown]
# # FORECASTING MELI COSTS USING A SARIMA MODEL
#
# ## OBJECTIVE
#
# In order to understand how a SARIMA model works, we will be using the **statsmodel** package implementation (https://www.statsmodels.org/dev/examples/notebooks/generated/statespace_sarimax_stata.html) to try to forecast MercadoLibre (MELI) EC2 costs using a dataset with hourly data from operations of EC2 instance purchases during May 2019.

# %% [markdown]
# ## PACKAGES

# %%
import os # for handling files
import matplotlib
import matplotlib.pyplot as plt
import warnings # for handling warning messages
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import itertools # collection of tools for handling iterators
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
'''
provides classes and functions for the estimation of many different
statistical models, as well as for conducting statistical tests, 
and statistical data exploration.
'''
import pmdarima as pm 

'''
Pmdarima is a statistical library
'''

from influxdb_client import InfluxDBClient

matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# ## DATA PROCESSING
# ### LOADING

# %%
parameters = {
    "influx_client":{
        "url": "http://localhost:8086",
        "token": "lfxC2lYwGfnLPGt7viM80qZASpVFwu7z0ELorZEdAqyw5AH94V7TfgrpM8ga-vhtLd0LkxN2i5uKQ82_p2V7lg==",
        "org": "influxProject",
        "timeout" : 300000
    },
    "influx_write_api":{
        "bucket": "dailyMetricsETH",
        "batch_size": 800,
        "flush_interval": 10000
    }
}

# %%
query = ''' 
from(bucket: "dailyMetricsETH")
  |> range(start: 2018-12-25, stop: 2021-09-19)
  |> filter(fn: (r) => r["_measurement"] == "Daily_Prices_and_Volumes_for_Digital_Currency")
  |> filter(fn: (r) => r["Digital_Currency_Code"] == "ETH")
  |> filter(fn: (r) => r["_field"] == "4a_close" )
  |> drop(columns: ["_start", "_stop", "_field","_measurement", "Digital_Currency_Name", "Market_Code", "Market_Name"])
  |> rename(columns: {_value: "close", _time: "date", Digital_Currency_Code: "symbol"})
'''

# %%
with InfluxDBClient(url=parameters["influx_client"]["url"], token=parameters["influx_client"]["token"], org=parameters["influx_client"]["org"], timeout=parameters["influx_client"]["timeout"], enable_gzip=False, debug=True) as client:
    
    eth_close_prices = client.query_api().query_data_frame(org=parameters["influx_client"]["org"], query=query)
# Out:
# send: b'POST /api/v2/query?org=influxProject HTTP/1.1\r\nHost: localhost:8086\r\nAccept-Encoding: identity\r\nContent-Length: 735\r\nAccept: application/json\r\nContent-Type: application/json\r\nAuthorization: Token lfxC2lYwGfnLPGt7viM80qZASpVFwu7z0ELorZEdAqyw5AH94V7TfgrpM8ga-vhtLd0LkxN2i5uKQ82_p2V7lg==\r\nUser-Agent: influxdb-client-python/1.21.0\r\n\r\n'
# send: b'{"extern": {"imports": [], "body": []}, "query": " \\nfrom(bucket: \\"dailyMetricsETH\\")\\n  |> range(start: 2018-12-25, stop: 2021-09-19)\\n  |> filter(fn: (r) => r[\\"_measurement\\"] == \\"Daily_Prices_and_Volumes_for_Digital_Currency\\")\\n  |> filter(fn: (r) => r[\\"Digital_Currency_Code\\"] == \\"ETH\\")\\n  |> filter(fn: (r) => r[\\"_field\\"] == \\"4a_close\\" )\\n  |> drop(columns: [\\"_start\\", \\"_stop\\", \\"_field\\",\\"_measurement\\", \\"Digital_Currency_Name\\", \\"Market_Code\\", \\"Market_Name\\"])\\n  |> rename(columns: {_value: \\"close\\", _time: \\"date\\", Digital_Currency_Code: \\"symbol\\"})\\n", "dialect": {"header": true, "delimiter": ",", "annotations": ["datatype", "group", "default"], "commentPrefix": "#", "dateTimeFormat": "RFC3339"}}'
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Content-Type: text/csv; charset=utf-8
# header: Vary: Accept-Encoding
# header: Date: Mon, 20 Sep 2021 02:36:38 GMT
# header: Transfer-Encoding: chunked

# %%
eth_close_prices.head(5)
# Out:
#     result table                      date   close symbol
# 0  _result     0 2018-12-25 00:00:00+00:00  127.60    ETH
# 1  _result     0 2018-12-26 00:00:00+00:00  129.35    ETH
# 2  _result     0 2018-12-27 00:00:00+00:00  113.80    ETH
# 3  _result     0 2018-12-28 00:00:00+00:00  135.30    ETH
# 4  _result     0 2018-12-29 00:00:00+00:00  132.89    ETH

# %%
eth_close_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 0 to 998
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   result  999 non-null    object
#  1   table   999 non-null    object
#  2   date    999 non-null    datetime64[ns, UTC]
#  3   close   999 non-null    float64
#  4   symbol  999 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(1), object(3)
# memory usage: 46.8+ KB

# %%
eth_close_prices.drop(['result', 'table', 'symbol'], axis=1, inplace= True)
eth_close_prices.head(5)
# Out:
#                        date   close
# 0 2018-12-25 00:00:00+00:00  127.60
# 1 2018-12-26 00:00:00+00:00  129.35
# 2 2018-12-27 00:00:00+00:00  113.80
# 3 2018-12-28 00:00:00+00:00  135.30
# 4 2018-12-29 00:00:00+00:00  132.89

# %% [markdown]
# ### INDEXING
#
# We use time data as an index for our dataframe

# %%
eth_close_prices = eth_close_prices.set_index('date')

# %%
eth_close_prices.head(5)
# Out:
#                             close
# date
# 2018-12-25 00:00:00+00:00  127.60
# 2018-12-26 00:00:00+00:00  129.35
# 2018-12-27 00:00:00+00:00  113.80
# 2018-12-28 00:00:00+00:00  135.30
# 2018-12-29 00:00:00+00:00  132.89

# %% [markdown]
# ### RESAMPLING
# We resample data using a daily frequency

# %%
df_costs_monthly = df_costs['y'].resample('D').mean()

# %%
df_costs_monthly.head(5)
# Out:
# ds
# 2019-05-01    774.111453
# 2019-05-02    804.738605
# 2019-05-03    816.846227
# 2019-05-04    773.392662
# 2019-05-05    812.632086
# Freq: D, Name: y, dtype: float64

# %% [markdown]
# ### VISUALIZING
#
# #### EXPLORATORY VISUALIZATION
#
# We make an exploratory visulization of data using pyplot.
#
# First, we show a plot of the raw data

# %%
eth_close_prices.plot(figsize=(15, 6))
plt.title('ETH close price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
#plt.legend()
plt.savefig('ETH_close_price.png')
plt.show()

# %% [markdown]
# In order to see whether we can

# %%
eth_close_prices_first_diff = eth_close_prices.diff()
#df_costs_monthly_seasonal_diff = df_costs_monthly.diff(7)
#df_costs_monthly_seasonal_first_diff = df_costs_monthly_seasonal_diff.diff()

# %%
eth_close_prices_first_diff.plot(figsize=(15, 6))
plt.title('ETH close price (first diff)')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
#plt.legend()
plt.savefig('ETH_close_price_first_diff.png')
plt.show()

# %%
adf, pvalue, usedlag_, nobs_, critical_values_, icbest_ = adfuller(eth_close_prices_first_diff[1:])#df_costs_monthly_seasonal_first_diff[8:])

print(pvalue)
# Out:
# 6.655632999025107e-16

# %%
nobs_
# Out:
# 982

# %% [markdown]
# As we can see, we can reject $H_0$ hypothesis and claim **stationarity**. Let's see wether we can conclude something about model parameters analyzing **ACF** and **PACF**.

# %%
len(eth_close_prices_first_diff)
# Out:
# 999

# %% [markdown]
# Transformed time series can be seen in what follows.

# %%
fig,ax = plt.subplots(2,1,figsize=(15,8))
fig = sm.graphics.tsa.plot_acf(eth_close_prices_first_diff.dropna(), lags=997, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(eth_close_prices_first_diff.dropna(), lags=498, ax=ax[1])
ax[0].set_xlim(-0.1, 130)
ax[1].set_xlim(-0.1, 130)
ax[1].set_ylim(-0.25, 0.25)
plt.savefig('ETH_close_price_ACF_PACF_reduced.png')
plt.show()

# %%
# Out:
# 0.0005699360646698533

# %%
df_costs_monthly_seasonal_first_diff.plot(figsize=(15, 6))
plt.title('Amazon EC2 costs - May 2019 - Seasonal differences + First differences')
plt.xlabel('Date')
plt.ylabel('Cost (USD)')
#plt.legend()
plt.show(dd)

# %%
from statsmodels.tsa.stattools import adfuller
adf, pvalue, usedlag_, nobs_, critical_values_, icbest_ = adfuller(df_costs_monthly_seasonal_first_diff[8:])

print(pvalue)
# Out:
# 0.13809912549961395

# %% [markdown]
# ## FORECASTING PROCESS
# ### INTRODUCTION
#
# Seasonal Autoregressive Integrated Moving Average, SARIMA or Seasonal ARIMA, is an extension of ARIMA
# that explicitly supports univariate time series data with a seasonal component.
#
# It adds three new hyperparameters to specify the autoregression (AR), differencing (I), and moving
# average (MA) for the seasonal component of the series, as well as an additional parameter for the
# period of the seasonality.
#
# Configuring a SARIMA requires selecting hyperparameters for both the trend and seasonal elements of the series. Concretely, for the ARIMA part we have
#
# * p: Trend autoregression order
# * d: Trend difference order
# * q: Trend moving average order
#
# and for the seasonal elements,
#
# * P: Seasonal autoregressive order
# * D: Seasonal difference order
# * Q: Seasonal moving average order
# * m: The number of time steps for a single seasonal period
#
# Having this into account, we can denote a certain SARIMA model as
#
# **SARIMA(p,d,q)(P,D,Q)m**
#
# ### FINDING THE BEST MODEL

# %% [markdown]
# #### GRID SEARCH PROCESS
#
# We will perform a grid search process for finding the set of parameters that minimizes AIC. To do that, we prepare the grid

# %%
# we make three ranges (0,1) and store them in p, d, q respectively
p = d = q = range(0, 2) 
# we use itertools.product to make a cartesian product of p, d, q and then we store its results in a list called pdq
pdq = list(itertools.product(p, d, q))
# we do the same for the seasonal parameters, having set m = 7 (weekly seasonal period)
seasonal_pdq = [(x[0], x[1], x[2], 7) for x in pdq]

# %%
print('Examples of parameter combinations for Seasonal ARIMA...')
f"SARIMA: {pdq[0]} x {seasonal_pdq[1]} " \
f"SARIMA: {pdq[1]} x {seasonal_pdq[2]} " \
f"SARIMA: {pdq[2]} x {seasonal_pdq[0]} " \
f"SARIMA: {pdq[1]} x {seasonal_pdq[1]} "
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# 'SARIMA: (0, 0, 0) x (0, 0, 1, 7) SARIMA: (0, 0, 1) x (0, 1, 0, 7) SARIMA: (0, 1, 0) x (0, 0, 0, 7) SARIMA: (0, 0, 1) x (0, 0, 1, 7) '

# %% [markdown]
# and then we fit the SARIMA model for each combination of parameters in the grid, compare the AICs and choose the parameter set that minimizes it:

# %%
arima_parameters = []
seasonal_parameters = []
AIC = []

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            # SARIMAX MODEL INITIALIZATION
            sarimax = sm.tsa.statespace.SARIMAX(df_costs_monthly,
                                            order=param,
                                            seasonal_order=param_seasonal)
            
            # SARIMAX MODEL FITTING
            fitted_sarimax = sarimax.fit(max_iter = 50, method = 'powell')
            
            arima_parameters.append(param)
            
            seasonal_parameters.append(param_seasonal)
            
            AIC.append(fitted_sarimax.aic)
            
            print('SARIMA{},{} - AIC:{}'.format(param, param_seasonal, np.round(fitted_sarimax.aic,2)))

        except:
            continue

# we obtain index for minimum AIC

min_AIC_index = AIC.index(min(AIC))

f'The optimum set of parameters for SARIMA model is [p,d,q]: {arima_parameters[min_AIC_index]}, [P,D,Q,m]: {seasonal_parameters[min_AIC_index]}. For that choice we get an AIC index of {np.round(AIC[min_AIC_index],2)}'
# Out:
# Optimization terminated successfully.
#          Current function value: 8.239448
#          Iterations: 1
#          Function evaluations: 32
# SARIMA(0, 0, 0),(0, 0, 0, 7) - AIC:512.85
# Optimization terminated successfully.
#          Current function value: 7.846187
#          Iterations: 4
#          Function evaluations: 108
# SARIMA(0, 0, 0),(0, 0, 1, 7) - AIC:490.46
# Optimization terminated successfully.
#          Current function value: 4.626168
#          Iterations: 2
#          Function evaluations: 34
# SARIMA(0, 0, 0),(0, 1, 0, 7) - AIC:288.82
# Optimization terminated successfully.
#          Current function value: 4.625385
#          Iterations: 2
#          Function evaluations: 71
# SARIMA(0, 0, 0),(0, 1, 1, 7) - AIC:290.77
# Optimization terminated successfully.
#          Current function value: 6.486690
#          Iterations: 3
#          Function evaluations: 93
# SARIMA(0, 0, 0),(1, 0, 0, 7) - AIC:406.17
# Optimization terminated successfully.
#          Current function value: 6.485611
#          Iterations: 5
#          Function evaluations: 204
# SARIMA(0, 0, 0),(1, 0, 1, 7) - AIC:408.11
# Optimization terminated successfully.
#          Current function value: 4.624858
#          Iterations: 2
#          Function evaluations: 46
# SARIMA(0, 0, 0),(1, 1, 0, 7) - AIC:290.74
# Optimization terminated successfully.
#          Current function value: 4.624437
#          Iterations: 2
#          Function evaluations: 88
# SARIMA(0, 0, 0),(1, 1, 1, 7) - AIC:292.72
# Optimization terminated successfully.
#          Current function value: 7.623839
#          Iterations: 3
#          Function evaluations: 88
# SARIMA(0, 0, 1),(0, 0, 0, 7) - AIC:476.68
# Optimization terminated successfully.
#          Current function value: 7.258401
#          Iterations: 5
#          Function evaluations: 273
# SARIMA(0, 0, 1),(0, 0, 1, 7) - AIC:456.02
# Optimization terminated successfully.
#          Current function value: 4.273686
#          Iterations: 3
#          Function evaluations: 79
# SARIMA(0, 0, 1),(0, 1, 0, 7) - AIC:268.97
# Optimization terminated successfully.
#          Current function value: 4.270714
#          Iterations: 3
#          Function evaluations: 115
# SARIMA(0, 0, 1),(0, 1, 1, 7) - AIC:270.78
# Optimization terminated successfully.
#          Current function value: 6.004812
#          Iterations: 5
#          Function evaluations: 238
# SARIMA(0, 0, 1),(1, 0, 0, 7) - AIC:378.3
# Optimization terminated successfully.
#          Current function value: 6.007544
#          Iterations: 6
#          Function evaluations: 326
# SARIMA(0, 0, 1),(1, 0, 1, 7) - AIC:380.47
# Optimization terminated successfully.
#          Current function value: 4.267901
#          Iterations: 3
#          Function evaluations: 111
# SARIMA(0, 0, 1),(1, 1, 0, 7) - AIC:270.61
# Optimization terminated successfully.
#          Current function value: 4.255198
#          Iterations: 6
#          Function evaluations: 292
# SARIMA(0, 0, 1),(1, 1, 1, 7) - AIC:271.82
# Optimization terminated successfully.
#          Current function value: 4.922477
#          Iterations: 1
#          Function evaluations: 10
# SARIMA(0, 1, 0),(0, 0, 0, 7) - AIC:307.19
# Optimization terminated successfully.
#          Current function value: 4.908452
#          Iterations: 2
#          Function evaluations: 46
# SARIMA(0, 1, 0),(0, 0, 1, 7) - AIC:308.32
# Optimization terminated successfully.
#          Current function value: 3.874608
#          Iterations: 2
#          Function evaluations: 36
# SARIMA(0, 1, 0),(0, 1, 0, 7) - AIC:242.23
# Optimization terminated successfully.
#          Current function value: 3.731462
#          Iterations: 3
#          Function evaluations: 77
# SARIMA(0, 1, 0),(0, 1, 1, 7) - AIC:235.35
# Optimization terminated successfully.
#          Current function value: 4.893890
#          Iterations: 2
#          Function evaluations: 47
# SARIMA(0, 1, 0),(1, 0, 0, 7) - AIC:307.42
# Optimization terminated successfully.
#          Current function value: 4.819561
#          Iterations: 6
#          Function evaluations: 217
# SARIMA(0, 1, 0),(1, 0, 1, 7) - AIC:304.81
# Optimization terminated successfully.
#          Current function value: 3.677848
#          Iterations: 2
#          Function evaluations: 46
# SARIMA(0, 1, 0),(1, 1, 0, 7) - AIC:232.03
# Optimization terminated successfully.
#          Current function value: 3.683229
#          Iterations: 4
#          Function evaluations: 160
# SARIMA(0, 1, 0),(1, 1, 1, 7) - AIC:234.36
# Optimization terminated successfully.
#          Current function value: 4.871782
#          Iterations: 1
#          Function evaluations: 21
# SARIMA(0, 1, 1),(0, 0, 0, 7) - AIC:306.05
# Optimization terminated successfully.
#          Current function value: 4.847044
#          Iterations: 2
#          Function evaluations: 76
# SARIMA(0, 1, 1),(0, 0, 1, 7) - AIC:306.52
# Optimization terminated successfully.
#          Current function value: 3.798783
#          Iterations: 2
#          Function evaluations: 47
# SARIMA(0, 1, 1),(0, 1, 0, 7) - AIC:239.52
# Optimization terminated successfully.
#          Current function value: 3.712681
#          Iterations: 3
#          Function evaluations: 113
# SARIMA(0, 1, 1),(0, 1, 1, 7) - AIC:236.19
# Optimization terminated successfully.
#          Current function value: 4.827609
#          Iterations: 2
#          Function evaluations: 69
# SARIMA(0, 1, 1),(1, 0, 0, 7) - AIC:305.31
# Optimization terminated successfully.
#          Current function value: 4.786369
#          Iterations: 6
#          Function evaluations: 289
# SARIMA(0, 1, 1),(1, 0, 1, 7) - AIC:304.75
# Optimization terminated successfully.
#          Current function value: 3.676752
#          Iterations: 4
#          Function evaluations: 143
# SARIMA(0, 1, 1),(1, 1, 0, 7) - AIC:233.96
# Optimization terminated successfully.
#          Current function value: 3.676923
#          Iterations: 4
#          Function evaluations: 190
# SARIMA(0, 1, 1),(1, 1, 1, 7) - AIC:235.97
# Optimization terminated successfully.
#          Current function value: 5.189768
#          Iterations: 2
#          Function evaluations: 65
# SARIMA(1, 0, 0),(0, 0, 0, 7) - AIC:325.77
# Optimization terminated successfully.
#          Current function value: 5.176015
#          Iterations: 2
#          Function evaluations: 88
# SARIMA(1, 0, 0),(0, 0, 1, 7) - AIC:326.91
# Optimization terminated successfully.
#          Current function value: 4.051382
#          Iterations: 2
#          Function evaluations: 42
# SARIMA(1, 0, 0),(0, 1, 0, 7) - AIC:255.19
# Optimization terminated successfully.
#          Current function value: 3.907505
#          Iterations: 6
#          Function evaluations: 232
# SARIMA(1, 0, 0),(0, 1, 1, 7) - AIC:248.27
# Optimization terminated successfully.
#          Current function value: 5.161948
#          Iterations: 3
#          Function evaluations: 122
# SARIMA(1, 0, 0),(1, 0, 0, 7) - AIC:326.04
# Optimization terminated successfully.
#          Current function value: 5.104003
#          Iterations: 7
#          Function evaluations: 372
# SARIMA(1, 0, 0),(1, 0, 1, 7) - AIC:324.45
# Optimization terminated successfully.
#          Current function value: 3.846926
#          Iterations: 4
#          Function evaluations: 137
# SARIMA(1, 0, 0),(1, 1, 0, 7) - AIC:244.51
# Optimization terminated successfully.
#          Current function value: 3.845722
#          Iterations: 4
#          Function evaluations: 186
# SARIMA(1, 0, 0),(1, 1, 1, 7) - AIC:246.43
# Optimization terminated successfully.
#          Current function value: 5.138935
#          Iterations: 2
#          Function evaluations: 85
# SARIMA(1, 0, 1),(0, 0, 0, 7) - AIC:324.61
# Optimization terminated successfully.
#          Current function value: 5.114647
#          Iterations: 3
#          Function evaluations: 151
# SARIMA(1, 0, 1),(0, 0, 1, 7) - AIC:325.11
# Optimization terminated successfully.
#          Current function value: 3.966651
#          Iterations: 2
#          Function evaluations: 72
# SARIMA(1, 0, 1),(0, 1, 0, 7) - AIC:251.93
# Optimization terminated successfully.
#          Current function value: 3.889327
#          Iterations: 7
#          Function evaluations: 351
# SARIMA(1, 0, 1),(0, 1, 1, 7) - AIC:249.14
# Optimization terminated successfully.
#          Current function value: 5.095364
#          Iterations: 4
#          Function evaluations: 207
# SARIMA(1, 0, 1),(1, 0, 0, 7) - AIC:323.91
# Optimization terminated successfully.
#          Current function value: 5.055299
#          Iterations: 8
#          Function evaluations: 511
# SARIMA(1, 0, 1),(1, 0, 1, 7) - AIC:323.43
# Optimization terminated successfully.
#          Current function value: 3.845743
#          Iterations: 4
#          Function evaluations: 188
# SARIMA(1, 0, 1),(1, 1, 0, 7) - AIC:246.44
# Optimization terminated successfully.
#          Current function value: 3.844590
#          Iterations: 4
#          Function evaluations: 226
# SARIMA(1, 0, 1),(1, 1, 1, 7) - AIC:248.36
# Optimization terminated successfully.
#          Current function value: 4.885980
#          Iterations: 1
#          Function evaluations: 24
# SARIMA(1, 1, 0),(0, 0, 0, 7) - AIC:306.93
# Optimization terminated successfully.
#          Current function value: 4.858665
#          Iterations: 3
#          Function evaluations: 120
# SARIMA(1, 1, 0),(0, 0, 1, 7) - AIC:307.24
# Optimization terminated successfully.
#          Current function value: 3.786245
#          Iterations: 1
#          Function evaluations: 24
# SARIMA(1, 1, 0),(0, 1, 0, 7) - AIC:238.75
# Optimization terminated successfully.
#          Current function value: 3.707460
#          Iterations: 4
#          Function evaluations: 152
# SARIMA(1, 1, 0),(0, 1, 1, 7) - AIC:235.86
# Optimization terminated successfully.
#          Current function value: 4.834845
#          Iterations: 2
#          Function evaluations: 71
# SARIMA(1, 1, 0),(1, 0, 0, 7) - AIC:305.76
# Optimization terminated successfully.
#          Current function value: 4.785639
#          Iterations: 7
#          Function evaluations: 330
# SARIMA(1, 1, 0),(1, 0, 1, 7) - AIC:304.71
# Optimization terminated successfully.
#          Current function value: 3.676859
#          Iterations: 4
#          Function evaluations: 142
# SARIMA(1, 1, 0),(1, 1, 0, 7) - AIC:233.97
# Optimization terminated successfully.
#          Current function value: 3.676719
#          Iterations: 6
#          Function evaluations: 282
# SARIMA(1, 1, 0),(1, 1, 1, 7) - AIC:235.96
# Optimization terminated successfully.
#          Current function value: 4.870045
#          Iterations: 1
#          Function evaluations: 36
# SARIMA(1, 1, 1),(0, 0, 0, 7) - AIC:307.94
# Optimization terminated successfully.
#          Current function value: 4.846755
#          Iterations: 4
#          Function evaluations: 202
# SARIMA(1, 1, 1),(0, 0, 1, 7) - AIC:308.5
# Optimization terminated successfully.
#          Current function value: 3.786150
#          Iterations: 1
#          Function evaluations: 34
# SARIMA(1, 1, 1),(0, 1, 0, 7) - AIC:240.74
# Optimization terminated successfully.
#          Current function value: 3.704651
#          Iterations: 7
#          Function evaluations: 338
# SARIMA(1, 1, 1),(0, 1, 1, 7) - AIC:237.69
# Optimization terminated successfully.
#          Current function value: 4.827570
#          Iterations: 4
#          Function evaluations: 193
# SARIMA(1, 1, 1),(1, 0, 0, 7) - AIC:307.31
# Optimization terminated successfully.
#          Current function value: 4.786285
#          Iterations: 6
#          Function evaluations: 365
# SARIMA(1, 1, 1),(1, 0, 1, 7) - AIC:306.75
# Optimization terminated successfully.
#          Current function value: 3.676847
#          Iterations: 4
#          Function evaluations: 186
# SARIMA(1, 1, 1),(1, 1, 0, 7) - AIC:235.96
# Optimization terminated successfully.
#          Current function value: 3.676784
#          Iterations: 5
#          Function evaluations: 301
# SARIMA(1, 1, 1),(1, 1, 1, 7) - AIC:237.96
# 'The optimum set of parameters for SARIMA model is [p,d,q]: (0, 1, 0), [P,D,Q,m]: (1, 1, 0, 7). For that choice we get an AIC index of 232.03'

# %% [markdown]
# ### MODEL FITTING
#
# Having found the set of parameters that minimizes AIC, we

# %%
sarimax_object = sm.tsa.statespace.SARIMAX(df_costs_monthly,
                                order=(0, 1, 0),
                                seasonal_order=(1, 1, 0, 7))
sarimax_model = sarimax_object.fit(max_iter = 100, method = 'powell')
sarimax_model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 3.677848
#          Iterations: 2
#          Function evaluations: 46
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                   31
# Model:             SARIMAX(0, 1, 0)x(1, 1, 0, 7)   Log Likelihood                -114.013
# Date:                           Wed, 25 Aug 2021   AIC                            232.027
# Time:                                   12:12:28   BIC                            234.298
# Sample:                               05-01-2019   HQIC                           232.598
#                                     - 05-31-2019
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L7       -0.7416      0.170     -4.356      0.000      -1.075      -0.408
# sigma2       930.0224    442.015      2.104      0.035      63.689    1796.356
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 1.44
# Prob(Q):                              0.90   Prob(JB):                         0.49
# Heteroskedasticity (H):               1.63   Skew:                            -0.08
# Prob(H) (two-sided):                  0.51   Kurtosis:                         1.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# #### RESIDUAL ANALYSIS

# %%
sarimax_model.plot_diagnostics(figsize=(16, 8))
plt.show()

# %% [markdown]
# As we can see in the **Residuals plot**, they seem to fluctuate around zero and also to have uniform variance. Looking at the **Density plot** we find a dsitribution that resembles a normal one, but it's not quite well defined. As per the **Normal Q-Q plot**, fluctuations around the identity line are small, signaling the absence of skewedness. Finally, the **Correlogram** or **ACF plot** seems to indicate that no correlation between residuals is present at the stablished significance level (0.05).
#
# In order to statistically prove wether the residuals are correlated or not we can perform a Ljung-Box test (https://en.wikipedia.org/wiki/Ljung–Box_test):

# %%
residuals_ljungbox_test_results = sm.stats.acorr_ljungbox(sarimax_model.resid, model_df=0, lags=[10], return_df=True)
print(residuals_ljungbox_test_results)
# Out:
#      lb_stat  lb_pvalue
# 10  7.864767   0.642044

# %% [markdown]
# As we can see, we have the Ljung-Box statistic $Q=7.86$ and it's p-value equal to 0.642. This means that we are in position not to reject $H_0$, i.e., there is no serial correlation between residuals.

# %% [markdown]
# #### LATE TAIL COMPARISON
#
# Let's compare the model with the last week of the series to see how it performs.

# %%
pred = sarimax_model.get_prediction(start=pd.to_datetime('2019-05-25'), dynamic=False)
pred_ci = pred.conf_int()
ax = df_costs_monthly['2019-05-01':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Cost (USD)')
plt.legend()
plt.show()

# %% [markdown]
# We see its performance is acceptable.

# %% [markdown]
# #### FORECAST
#
# Now that we have tested everything and we are sure where we are heading at, let's do a 1-week forecast.

# %%
pred_uc = sarimax_model.get_forecast(steps=7)
pred_ci = pred_uc.conf_int()
ax = df_costs_monthly.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='1-week forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Number')
plt.legend()
plt.show()

# %% [markdown]
# ## USING PMDARIMA PACKAGE TO AUTOMATIZE THE WHOLE PROCESS
#
# Pmdarima (originally pyramid-arima, for the anagram of 'py' + 'arima') is a statistical library designed to fill the void in Python's time series analysis capabilities. This includes:
#
# - The equivalent of R's auto.arima functionality
# - A collection of statistical tests of stationarity and seasonality
# - Time series utilities, such as differencing and inverse differencing
# - Numerous endogenous and exogenous transformers and featurizers, including Box-Cox and Fourier transformations
# - Seasonal time series decompositions
# - Cross-validation utilities
# - A rich collection of built-in time series datasets for prototyping and examples
# - Scikit-learn-esque pipelines to consolidate your estimators and promote productionization
#
# Pmdarima wraps statsmodels under the hood, but is designed with an interface that's familiar to users coming from a scikit-learn background.
#
# ### FINDING THE BEST SARIMA MODEL

# %%
# Seasonal - fit stepwise auto-ARIMA
import pmdarima as pm
smodel = pm.auto_arima(df_costs_monthly, start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=7,
                         start_P=0, seasonal=True,
                         start_d=0, max_d=1,#d=None
                         D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=False, 
                         stepwise=True)

smodel.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[7]             : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,0)(0,1,0)[7]             : AIC=242.226, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[7]             : AIC=233.965, Time=0.03 sec
#  ARIMA(0,1,1)(0,1,1)[7]             : AIC=inf, Time=0.07 sec
#  ARIMA(1,1,0)(0,1,0)[7]             : AIC=238.747, Time=0.01 sec
#  ARIMA(1,1,0)(2,1,0)[7]             : AIC=235.958, Time=0.05 sec
#  ARIMA(1,1,0)(1,1,1)[7]             : AIC=235.956, Time=0.07 sec
#  ARIMA(1,1,0)(0,1,1)[7]             : AIC=235.853, Time=0.03 sec
# /Users/homocuadratus/Projects/time-series-final-work/time-series-final-work-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  ARIMA(1,1,0)(2,1,1)[7]             : AIC=237.858, Time=0.21 sec
#  ARIMA(0,1,0)(1,1,0)[7]             : AIC=232.026, Time=0.01 sec
#  ARIMA(0,1,0)(2,1,0)[7]             : AIC=234.011, Time=0.03 sec
#  ARIMA(0,1,0)(1,1,1)[7]             : AIC=33907192.642, Time=0.02 sec
#  ARIMA(0,1,0)(0,1,1)[7]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,1,0)(2,1,1)[7]             : AIC=33907186.983, Time=0.04 sec
#  ARIMA(0,1,1)(1,1,0)[7]             : AIC=233.959, Time=0.03 sec
#  ARIMA(1,1,1)(1,1,0)[7]             : AIC=234.973, Time=0.08 sec
#  ARIMA(0,1,0)(1,1,0)[7] intercept   : AIC=234.004, Time=0.03 sec
#
# Best model:  ARIMA(0,1,0)(1,1,0)[7]
# Total fit time: 0.878 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                   31
# Model:             SARIMAX(0, 1, 0)x(1, 1, 0, 7)   Log Likelihood                -114.013
# Date:                           Wed, 25 Aug 2021   AIC                            232.026
# Time:                                   17:17:49   BIC                            234.297
# Sample:                                        0   HQIC                           232.597
#                                             - 31
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L7       -0.7441      0.170     -4.384      0.000      -1.077      -0.411
# sigma2       927.6328    439.360      2.111      0.035      66.503    1788.763
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 1.43
# Prob(Q):                              0.90   Prob(JB):                         0.49
# Heteroskedasticity (H):               1.64   Skew:                            -0.08
# Prob(H) (two-sided):                  0.50   Kurtosis:                         1.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# order=(0, 1, 0),
# seasonal_order=(1, 1, 0, 7)

# %% [markdown]
# As we can see, the resultant model is the same we obtained before working by hand.
